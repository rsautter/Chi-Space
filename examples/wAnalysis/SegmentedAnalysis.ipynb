# %%
# !pip install --force-reinstall git+https://github.com/rsautter/Chi-Space/
# Out:
# Collecting git+https://github.com/rsautter/Chi-Space/
#   Cloning https://github.com/rsautter/Chi-Space/ to /tmp/pip-req-build-s9i_6kto
#   Running command git clone -q https://github.com/rsautter/Chi-Space/ /tmp/pip-req-build-s9i_6kto
#   Resolved https://github.com/rsautter/Chi-Space/ to commit 07196d56168c93ee3f484685ef3c4e865b92d454
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: Chi-Space
#   Building wheel for Chi-Space (PEP 517) ... done
#   Created wheel for Chi-Space: filename=Chi_Space-0.2-py3-none-any.whl size=11459 sha256=280c5a3bd1316a0c8014d4a7c68dc1c2161abf9f20311c482b1433996e60c62f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i3xr5oin/wheels/5c/05/52/fc90c5e74cc923277afeac4910f3460e0304d0ba11171456cb
# Successfully built Chi-Space
# Installing collected packages: Chi-Space
#   Attempting uninstall: Chi-Space
#     Found existing installation: Chi-Space 0.2
#     Uninstalling Chi-Space-0.2:
#       Successfully uninstalled Chi-Space-0.2
# Successfully installed Chi-Space-0.2

# %%
import chi 
import numpy as np
import matplotlib.pyplot as plt

# %%
sw = chi.get_SolarWind()
print(sw, len(sw))
# Out:
# [ 0.26574397  0.24393439  0.24756932 ... -0.17044773 -0.17590012
#  -0.15772547] 4096

# %%
sw_s = segmentPeak(sw)
print(sw_s,len(sw_s))
# Out:
# [0.11125941 0.12943407 0.02947347 ... 0.16033098 0.14397379 0.13852139] 1024

# %%
plt.figure()
plt.plot(sw)
plt.figure()
plt.plot(sw_s)
plt.show()
